# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelbraf/oscar-winners-notebook/blob/master/oscar_winners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

import numpy as np
import os
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# importando o arquivo
oscar_winners = pd.read_csv('Oscars-demographics-DFE.csv', encoding='latin1', sep=',')
oscar_winners.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  670454353    False   finalized                   3      2/10/15 3:45
# 1  670454354    False   finalized                   3      2/10/15 2:03
# 2  670454355    False   finalized                   3      2/10/15 2:05
# 3  670454356    False   finalized                   3      2/10/15 2:04
# 4  670454357    False   finalized                   3      2/10/15 1:48
#
#            birthplace  birthplace:confidence date_of_birth  \
# 0   Chisinau, Moldova                    1.0   30-Sep-1895
# 1   Glasgow, Scotland                    1.0    2-Feb-1886
# 2   Chisinau, Moldova                    1.0   30-Sep-1895
# 3         Chicago, Il                    1.0   23-Feb-1899
# 4  Salt Lake City, Ut                    1.0   23-Apr-1894
#
#    date_of_birth:confidence race_ethnicity  ...          award  \
# 0                       1.0          White  ...  Best Director
# 1                       1.0          White  ...  Best Director
# 2                       1.0          White  ...  Best Director
# 3                       1.0          White  ...  Best Director
# 4                       1.0          White  ...  Best Director
#
#                                       biourl  birthplace_gold  \
# 0  http://www.nndb.com/people/320/000043191/              NaN
# 1  http://www.nndb.com/people/626/000042500/              NaN
# 2  http://www.nndb.com/people/320/000043191/              NaN
# 3  http://www.nndb.com/people/544/000041421/              NaN
# 4  http://www.nndb.com/people/292/000044160/              NaN
#
#   date_of_birth_gold                           movie           person  \
# 0                NaN             Two Arabian Knights  Lewis Milestone
# 1                NaN                 The Divine Lady      Frank Lloyd
# 2                NaN  All Quiet on the Western Front  Lewis Milestone
# 3                NaN                          Skippy    Norman Taurog
# 4                NaN                        Bad Girl    Frank Borzage
#
#    race_ethnicity_gold religion_gold sexual_orientation_gold  \
# 0                  NaN           NaN                     NaN
# 1                  NaN           NaN                     NaN
# 2                  NaN           NaN                     NaN
# 3                  NaN           NaN                     NaN
# 4                  NaN           NaN                     NaN
#
#   year_of_award_gold
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 27 columns]

# %%
# verificando a quantidade de linhas e colunas
oscar_winners.shape
# Out:
# (441, 27)

# %%
# removendo duplicatas e verificando a quantidade
oscar_winners = oscar_winners.drop_duplicates()
oscar_winners.shape
# Out:
# (441, 27)

# %%
# verificando a quantidade de valores nulos que existem na base
oscar_winners.isnull().sum()
# Out:
# _unit_id                           0
# _golden                            0
# _unit_state                        0
# _trusted_judgments                 0
# _last_judgment_at                 25
# birthplace                         0
# birthplace:confidence              0
# date_of_birth                      0
# date_of_birth:confidence           0
# race_ethnicity                     0
# race_ethnicity:confidence          0
# religion                           0
# religion:confidence                0
# sexual_orientation                 0
# sexual_orientation:confidence      0
# year_of_award                      0
# year_of_award:confidence           0
# award                              0
# biourl                             0
# birthplace_gold                  432
# date_of_birth_gold               433
# movie                              0
# person                             0
# race_ethnicity_gold              439
# religion_gold                    431
# sexual_orientation_gold          438
# year_of_award_gold               430
# dtype: int64

# %%
# criando colunas para marcar colunas que tinham valores nulos
oscar_winners['_last_judgment_at_nulls'] = np.where(oscar_winners['_last_judgment_at'].isnull(), 'null', 'n/a')
oscar_winners['birthplace_gold_nulls'] = np.where(oscar_winners['birthplace_gold'].isnull(), 'null', 'n/a')
oscar_winners['date_of_birth_gold_nulls'] = np.where(oscar_winners['date_of_birth_gold'].isnull(), 'null', 'n/a')
oscar_winners['race_ethnicity_gold_nulls'] = np.where(oscar_winners['race_ethnicity_gold'].isnull(), 'null', 'n/a')
oscar_winners['religion_gold_nulls'] = np.where(oscar_winners['religion_gold'].isnull(), 'null', 'n/a')
oscar_winners['sexual_orientation_gold_nulls'] = np.where(oscar_winners['sexual_orientation_gold'].isnull(), 'null', 'n/a')
oscar_winners['year_of_award_gold_nulls'] = np.where(oscar_winners['year_of_award_gold'].isnull(), 'null', 'n/a')

# verificando a base
oscar_winners.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  670454353    False   finalized                   3      2/10/15 3:45
# 1  670454354    False   finalized                   3      2/10/15 2:03
# 2  670454355    False   finalized                   3      2/10/15 2:05
# 3  670454356    False   finalized                   3      2/10/15 2:04
# 4  670454357    False   finalized                   3      2/10/15 1:48
#
#            birthplace  birthplace:confidence date_of_birth  \
# 0   Chisinau, Moldova                    1.0   30-Sep-1895
# 1   Glasgow, Scotland                    1.0    2-Feb-1886
# 2   Chisinau, Moldova                    1.0   30-Sep-1895
# 3         Chicago, Il                    1.0   23-Feb-1899
# 4  Salt Lake City, Ut                    1.0   23-Apr-1894
#
#    date_of_birth:confidence race_ethnicity  ...  religion_gold  \
# 0                       1.0          White  ...            NaN
# 1                       1.0          White  ...            NaN
# 2                       1.0          White  ...            NaN
# 3                       1.0          White  ...            NaN
# 4                       1.0          White  ...            NaN
#
#   sexual_orientation_gold  year_of_award_gold _last_judgment_at_nulls  \
# 0                     NaN                 NaN                     n/a
# 1                     NaN                 NaN                     n/a
# 2                     NaN                 NaN                     n/a
# 3                     NaN                 NaN                     n/a
# 4                     NaN                 NaN                     n/a
#
#    birthplace_gold_nulls  date_of_birth_gold_nulls  race_ethnicity_gold_nulls  \
# 0                   null                      null                       null
# 1                   null                      null                       null
# 2                   null                      null                       null
# 3                   null                      null                       null
# 4                   null                      null                       null
#
#   religion_gold_nulls sexual_orientation_gold_nulls year_of_award_gold_nulls
# 0                null                          null                     null
# 1                null                          null                     null
# 2                null                          null                     null
# 3                null                          null                     null
# 4                null                          null                     null
#
# [5 rows x 34 columns]

# %%
# substituindo os valores nulos
# as colunas last_judgement, date_of_birth  year_of_award serão substituídas por 0
# as demais colunas serão substituídas por "N/A"
oscar_winners['_last_judgment_at'] = oscar_winners['_last_judgment_at'].fillna(0)
oscar_winners['date_of_birth_gold'] = oscar_winners['date_of_birth_gold'].fillna(0)
oscar_winners['year_of_award_gold'] = oscar_winners['year_of_award_gold'].fillna(0)

oscar_winners['birthplace_gold'] = oscar_winners['birthplace_gold'].fillna('N/A')
oscar_winners['race_ethnicity_gold'] = oscar_winners['race_ethnicity_gold'].fillna('N/A')
oscar_winners['religion_gold'] = oscar_winners['religion_gold'].fillna('N/A')
oscar_winners['sexual_orientation_gold'] = oscar_winners['sexual_orientation_gold'].fillna('N/A')

# verificando se realmente todas as células nulas foram preenchidas
oscar_winners.isnull().sum()
# Out:
# _unit_id                         0
# _golden                          0
# _unit_state                      0
# _trusted_judgments               0
# _last_judgment_at                0
# birthplace                       0
# birthplace:confidence            0
# date_of_birth                    0
# date_of_birth:confidence         0
# race_ethnicity                   0
# race_ethnicity:confidence        0
# religion                         0
# religion:confidence              0
# sexual_orientation               0
# sexual_orientation:confidence    0
# year_of_award                    0
# year_of_award:confidence         0
# award                            0
# biourl                           0
# birthplace_gold                  0
# date_of_birth_gold               0
# movie                            0
# person                           0
# race_ethnicity_gold              0
# religion_gold                    0
# sexual_orientation_gold          0
# year_of_award_gold               0
# _last_judgment_at_nulls          0
# birthplace_gold_nulls            0
# date_of_birth_gold_nulls         0
# race_ethnicity_gold_nulls        0
# religion_gold_nulls              0
# sexual_orientation_gold_nulls    0
# year_of_award_gold_nulls         0
# dtype: int64

# %%
# colocando ambas as colunas last judgement at e date of birth em formato de data
oscar_winners['_last_judgment_at'] = pd.to_datetime(oscar_winners['_last_judgment_at'])
oscar_winners['date_of_birth_gold'] = pd.to_datetime(oscar_winners['date_of_birth_gold'])

# verificando se o ajuste foi bem sucedido
oscar_winners.head()
# Out:
# <ipython-input-11-c61f954017ef>:2: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#     _unit_id  _golden _unit_state  _trusted_judgments   _last_judgment_at  \
# 0  670454353    False   finalized                   3 2015-02-10 03:45:00
# 1  670454354    False   finalized                   3 2015-02-10 02:03:00
# 2  670454355    False   finalized                   3 2015-02-10 02:05:00
# 3  670454356    False   finalized                   3 2015-02-10 02:04:00
# 4  670454357    False   finalized                   3 2015-02-10 01:48:00
#
#            birthplace  birthplace:confidence date_of_birth  \
# 0   Chisinau, Moldova                    1.0   30-Sep-1895
# 1   Glasgow, Scotland                    1.0    2-Feb-1886
# 2   Chisinau, Moldova                    1.0   30-Sep-1895
# 3         Chicago, Il                    1.0   23-Feb-1899
# 4  Salt Lake City, Ut                    1.0   23-Apr-1894
#
#    date_of_birth:confidence race_ethnicity  ...  religion_gold  \
# 0                       1.0          White  ...            N/A
# 1                       1.0          White  ...            N/A
# 2                       1.0          White  ...            N/A
# 3                       1.0          White  ...            N/A
# 4                       1.0          White  ...            N/A
#
#   sexual_orientation_gold  year_of_award_gold _last_judgment_at_nulls  \
# 0                     N/A                 0.0                     n/a
# 1                     N/A                 0.0                     n/a
# 2                     N/A                 0.0                     n/a
# 3                     N/A                 0.0                     n/a
# 4                     N/A                 0.0                     n/a
#
#    birthplace_gold_nulls  date_of_birth_gold_nulls  race_ethnicity_gold_nulls  \
# 0                   null                      null                       null
# 1                   null                      null                       null
# 2                   null                      null                       null
# 3                   null                      null                       null
# 4                   null                      null                       null
#
#   religion_gold_nulls sexual_orientation_gold_nulls year_of_award_gold_nulls
# 0                null                          null                     null
# 1                null                          null                     null
# 2                null                          null                     null
# 3                null                          null                     null
# 4                null                          null                     null
#
# [5 rows x 34 columns]

# %%
# renomeando colunas
oscar_winners = oscar_winners.rename(columns={'_unit_id': 'unit_id', '_golden': 'golden', '_unit_state': 'unit_state', '_trusted_judgments': 'trusted_judgments'})
oscar_winners.head()
# Out:
#      unit_id  golden unit-state  trusted_judgments   _last_judgment_at  \
# 0  670454353   False  finalized                  3 2015-02-10 03:45:00
# 1  670454354   False  finalized                  3 2015-02-10 02:03:00
# 2  670454355   False  finalized                  3 2015-02-10 02:05:00
# 3  670454356   False  finalized                  3 2015-02-10 02:04:00
# 4  670454357   False  finalized                  3 2015-02-10 01:48:00
#
#            birthplace  birthplace:confidence date_of_birth  \
# 0   Chisinau, Moldova                    1.0   30-Sep-1895
# 1   Glasgow, Scotland                    1.0    2-Feb-1886
# 2   Chisinau, Moldova                    1.0   30-Sep-1895
# 3         Chicago, Il                    1.0   23-Feb-1899
# 4  Salt Lake City, Ut                    1.0   23-Apr-1894
#
#    date_of_birth:confidence race_ethnicity  ...  religion_gold  \
# 0                       1.0          White  ...            N/A
# 1                       1.0          White  ...            N/A
# 2                       1.0          White  ...            N/A
# 3                       1.0          White  ...            N/A
# 4                       1.0          White  ...            N/A
#
#   sexual_orientation_gold  year_of_award_gold _last_judgment_at_nulls  \
# 0                     N/A                 0.0                     n/a
# 1                     N/A                 0.0                     n/a
# 2                     N/A                 0.0                     n/a
# 3                     N/A                 0.0                     n/a
# 4                     N/A                 0.0                     n/a
#
#    birthplace_gold_nulls  date_of_birth_gold_nulls  race_ethnicity_gold_nulls  \
# 0                   null                      null                       null
# 1                   null                      null                       null
# 2                   null                      null                       null
# 3                   null                      null                       null
# 4                   null                      null                       null
#
#   religion_gold_nulls sexual_orientation_gold_nulls year_of_award_gold_nulls
# 0                null                          null                     null
# 1                null                          null                     null
# 2                null                          null                     null
# 3                null                          null                     null
# 4                null                          null                     null
#
# [5 rows x 34 columns]
